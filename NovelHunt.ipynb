# %% [markdown]
# #This is NovelHunt your personal Book Recommender

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import csv
from pandas.errors import ParserError

# %%
def read_csv_skip_error_lines(file_path):
    try:
        rows = []
        with open(file_path, 'r', encoding='latin-1') as file:
            reader = csv.reader(file, delimiter=';')
            headers = next(reader)  # Read the header row
            rows.append(headers)  # Store headers

            # Process the remaining rows, skipping problematic lines
            for row in reader:
                if len(row) == len(headers):  # Check if the row matches the header length
                    rows.append(row)

        # Create DataFrame from cleaned rows
        df = pd.DataFrame(rows[1:], columns=rows[0])
        return df
    except Exception as e:
        print(f"Error reading file '{file_path}': {e}")
        return pd.DataFrame()

# %%
books = read_csv_skip_error_lines('data/BX-Books.csv')

# %%
books.head(2)
# Out:
#          ISBN           Book-Title           Book-Author Year-Of-Publication  \
# 0  0195153448  Classical Mythology    Mark P. O. Morford                2002
# 1  0002005018         Clara Callan  Richard Bruce Wright                2001
#
#                  Publisher                                        Image-URL-S  \
# 0  Oxford University Press  http://images.amazon.com/images/P/0195153448.0...
# 1    HarperFlamingo Canada  http://images.amazon.com/images/P/0002005018.0...
#
#                                          Image-URL-M  \
# 0  http://images.amazon.com/images/P/0195153448.0...
# 1  http://images.amazon.com/images/P/0002005018.0...
#
#                                          Image-URL-L
# 0  http://images.amazon.com/images/P/0195153448.0...
# 1  http://images.amazon.com/images/P/0002005018.0...

# %%
books.shape
# Out:
# (271357, 8)

# %%
books.columns
# Out:
# Index(['ISBN', 'Book-Title', 'Book-Author', 'Year-Of-Publication', 'Publisher',
#        'Image-URL-S', 'Image-URL-M', 'Image-URL-L'],
#       dtype='object')

# %%
books = books[['ISBN', 'Book-Title', 'Book-Author', 'Year-Of-Publication', 'Publisher',
       'Image-URL-S']]

# %%
books.head(2)
# Out:
#          ISBN           Book-Title           Book-Author Year-Of-Publication  \
# 0  0195153448  Classical Mythology    Mark P. O. Morford                2002
# 1  0002005018         Clara Callan  Richard Bruce Wright                2001
#
#                  Publisher                                        Image-URL-S
# 0  Oxford University Press  http://images.amazon.com/images/P/0195153448.0...
# 1    HarperFlamingo Canada  http://images.amazon.com/images/P/0002005018.0...

# %%
books.rename(columns={
    "Book-Title": "Title",
    "Book-Author": "Author",
    "Year-Of-Publication": "Year",
    "Publisher": "publisher",
    "Image-URL-S": "Img_url"}, inplace = True)

# %%
books.head()
# Out:
#          ISBN                                              Title  \
# 0  0195153448                                Classical Mythology
# 1  0002005018                                       Clara Callan
# 2  0060973129                               Decision in Normandy
# 3  0374157065  Flu: The Story of the Great Influenza Pandemic...
# 4  0393045218                             The Mummies of Urumchi
#
#                  Author  Year                   publisher  \
# 0    Mark P. O. Morford  2002     Oxford University Press
# 1  Richard Bruce Wright  2001       HarperFlamingo Canada
# 2          Carlo D'Este  1991             HarperPerennial
# 3      Gina Bari Kolata  1999        Farrar Straus Giroux
# 4       E. J. W. Barber  1999  W. W. Norton &amp; Company
#
#                                              Img_url
# 0  http://images.amazon.com/images/P/0195153448.0...
# 1  http://images.amazon.com/images/P/0002005018.0...
# 2  http://images.amazon.com/images/P/0060973129.0...
# 3  http://images.amazon.com/images/P/0374157065.0...
# 4  http://images.amazon.com/images/P/0393045218.0...

# %%
users = read_csv_skip_error_lines('data/BX-Users.csv')

# %%
users.head()
# Out:
#   User-ID                            Location   Age
# 0       1                  nyc, new york, usa  NULL
# 1       2           stockton, california, usa    18
# 2       3     moscow, yukon territory, russia  NULL
# 3       4           porto, v.n.gaia, portugal    17
# 4       5  farnborough, hants, united kingdom  NULL

# %%
ratings = read_csv_skip_error_lines('data/BX-Book-Ratings.csv')

# %%
ratings.head()
# Out:
#   User-ID        ISBN Book-Rating
# 0  276725  034545104X           0
# 1  276726  0155061224           5
# 2  276727  0446520802           0
# 3  276729  052165615X           3
# 4  276729  0521795028           6

# %%
ratings.shape
# Out:
# (1149780, 3)

# %%
print(books.shape)
print(users.shape)
print(ratings.shape)
# Out:
# (271357, 6)
# (278858, 3)
# (1149780, 3)

# %%
ratings.rename(columns={
    "User-ID": "user_id",
    "Book-Rating": "Rating"},inplace= True)

# %%
ratings.head()
# Out:
#   user_id        ISBN Rating
# 0  276725  034545104X      0
# 1  276726  0155061224      5
# 2  276727  0446520802      0
# 3  276729  052165615X      3
# 4  276729  0521795028      6

# %%
ratings["user_id"].value_counts()
# Out:
# user_id
# 11676     13602
# 198711     7550
# 153662     6109
# 98391      5891
# 35859      5850
#           ...
# 116180        1
# 116166        1
# 116154        1
# 116137        1
# 276723        1
# Name: count, Length: 105283, dtype: int64

# %%
ratings["user_id"].unique().shape
# Out:
# (105283,)

# %%
x = ratings['user_id'].value_counts() > 200

# %%
x[x].shape
# Out:
# (899,)

# %%
y = x[x].index

# %%
y
# Out:
# Index(['11676', '198711', '153662', '98391', '35859', '212898', '278418',
#        '76352', '110973', '235105',
#        ...
#        '260183', '73681', '44296', '155916', '9856', '274808', '28634',
#        '59727', '268622', '188951'],
#       dtype='object', name='user_id', length=899)

# %%
ratings = ratings[ratings['user_id'].isin(y)]

# %%
ratings.head()
# Out:
#      user_id        ISBN Rating
# 1456  277427  002542730X     10
# 1457  277427  0026217457      0
# 1458  277427  003008685X      8
# 1459  277427  0030615321      0
# 1460  277427  0060002050      0

# %%
ratings_with_books = ratings.merge(books, on ="ISBN")

# %%
ratings_with_books.head()
# Out:
#   user_id        ISBN Rating  \
# 0  277427  002542730X     10
# 1    3363  002542730X      0
# 2   11676  002542730X      6
# 3   12538  002542730X     10
# 4   13552  002542730X      0
#
#                                                Title             Author  Year  \
# 0  Politically Correct Bedtime Stories: Modern Ta...  James Finn Garner  1994
# 1  Politically Correct Bedtime Stories: Modern Ta...  James Finn Garner  1994
# 2  Politically Correct Bedtime Stories: Modern Ta...  James Finn Garner  1994
# 3  Politically Correct Bedtime Stories: Modern Ta...  James Finn Garner  1994
# 4  Politically Correct Bedtime Stories: Modern Ta...  James Finn Garner  1994
#
#                    publisher  \
# 0  John Wiley &amp; Sons Inc
# 1  John Wiley &amp; Sons Inc
# 2  John Wiley &amp; Sons Inc
# 3  John Wiley &amp; Sons Inc
# 4  John Wiley &amp; Sons Inc
#
#                                              Img_url
# 0  http://images.amazon.com/images/P/002542730X.0...
# 1  http://images.amazon.com/images/P/002542730X.0...
# 2  http://images.amazon.com/images/P/002542730X.0...
# 3  http://images.amazon.com/images/P/002542730X.0...
# 4  http://images.amazon.com/images/P/002542730X.0...

# %%
ratings_with_books.shape
# Out:
# (487668, 8)

# %%
num_rating = ratings_with_books.groupby('Title')['Rating'].count().reset_index()

# %%
num_rating.head()
# Out:
#                                                Title  Rating
# 0   A Light in the Storm: The Civil War Diary of ...       2
# 1                              Always Have Popsicles       1
# 2               Apple Magic (The Collector's series)       1
# 3   Beyond IBM: Leadership Marketing and Finance ...       1
# 4   Clifford Visita El Hospital (Clifford El Gran...       1

# %%
num_rating.rename(columns={"Rating":"Num_of_rating"},inplace=True)

# %%
num_rating.head()
# Out:
#                                                Title  Num_of_rating
# 0   A Light in the Storm: The Civil War Diary of ...              2
# 1                              Always Have Popsicles              1
# 2               Apple Magic (The Collector's series)              1
# 3   Beyond IBM: Leadership Marketing and Finance ...              1
# 4   Clifford Visita El Hospital (Clifford El Gran...              1

# %%
final_rating = ratings_with_books.merge(num_rating, on= 'Title')

# %%
final_rating.head()
# Out:
#   user_id        ISBN Rating  \
# 0  277427  002542730X     10
# 1    3363  002542730X      0
# 2   11676  002542730X      6
# 3   12538  002542730X     10
# 4   13552  002542730X      0
#
#                                                Title             Author  Year  \
# 0  Politically Correct Bedtime Stories: Modern Ta...  James Finn Garner  1994
# 1  Politically Correct Bedtime Stories: Modern Ta...  James Finn Garner  1994
# 2  Politically Correct Bedtime Stories: Modern Ta...  James Finn Garner  1994
# 3  Politically Correct Bedtime Stories: Modern Ta...  James Finn Garner  1994
# 4  Politically Correct Bedtime Stories: Modern Ta...  James Finn Garner  1994
#
#                    publisher  \
# 0  John Wiley &amp; Sons Inc
# 1  John Wiley &amp; Sons Inc
# 2  John Wiley &amp; Sons Inc
# 3  John Wiley &amp; Sons Inc
# 4  John Wiley &amp; Sons Inc
#
#                                              Img_url  Num_of_rating
# 0  http://images.amazon.com/images/P/002542730X.0...             82
# 1  http://images.amazon.com/images/P/002542730X.0...             82
# 2  http://images.amazon.com/images/P/002542730X.0...             82
# 3  http://images.amazon.com/images/P/002542730X.0...             82
# 4  http://images.amazon.com/images/P/002542730X.0...             82

# %%
final_rating.sample()
# Out:
#        user_id        ISBN Rating                                    Title  \
# 268655   30276  0843950641      6  The Very Virile Viking: (Cartoon Cover)
#
#              Author  Year      publisher  \
# 268655  Sandra Hill  2003  Leisure Books
#
#                                                   Img_url  Num_of_rating
# 268655  http://images.amazon.com/images/P/0843950641.0...              6

# %%
final_rating = final_rating[final_rating['Num_of_rating']>=50]

# %%
final_rating.sample(10)
# Out:
#        user_id        ISBN Rating  \
# 99891    16795  0385721420      0
# 4957    262399  0399501487      0
# 115278   17950  0451202341      0
# 186404  182085  0671034057     10
# 9915    180957  0553268880      0
# 49204    78973  0743467523      7
# 1429     25981  0312966091     10
# 6380    170229  0439420105      0
# 132623   81045  0312995423     10
# 450     141710  0060934417      0
#
#                                                     Title  \
# 99891                                         Three Junes
# 4957                                    Lord of the Flies
# 115278                                         Back Roads
# 186404                                    Now You See Her
# 9915                                  The Prince of Tides
# 49204                                        Dreamcatcher
# 1429    Three To Get Deadly : A Stephanie Plum Novel (...
# 6380     Harry Potter and the Chamber of Secrets (Book 2)
# 132623                      Digital Fortress : A Thriller
# 450                                    Bel Canto: A Novel
#
#                         Author  Year                publisher  \
# 99891              JULIA GLASS  2003                   Anchor
# 4957    William Gerald Golding  1959            Perigee Trade
# 115278            Tawni O'Dell  2001              Signet Book
# 186404            Linda Howard  1999             Pocket Books
# 9915                Pat Conroy  1987             Bantam Books
# 49204             Stephen King  2003                   Pocket
# 1429           Janet Evanovich  1998  St. Martin's Paperbacks
# 6380             J. K. Rowling  2002               Scholastic
# 132623               Dan Brown  2003       St. Martin's Press
# 450               Ann Patchett  2002                Perennial
#
#                                                   Img_url  Num_of_rating
# 99891   http://images.amazon.com/images/P/0385721420.0...             84
# 4957    http://images.amazon.com/images/P/0399501487.0...            120
# 115278  http://images.amazon.com/images/P/0451202341.0...            118
# 186404  http://images.amazon.com/images/P/0671034057.0...             52
# 9915    http://images.amazon.com/images/P/0553268880.0...            148
# 49204   http://images.amazon.com/images/P/0743467523.0...            161
# 1429    http://images.amazon.com/images/P/0312966091.0...            105
# 6380    http://images.amazon.com/images/P/0439420105.0...            183
# 132623  http://images.amazon.com/images/P/0312995423.0...             61
# 450     http://images.amazon.com/images/P/0060934417.0...            108

# %%
final_rating.shape
# Out:
# (61853, 9)

# %%
final_rating.drop_duplicates(['user_id', 'Title'], inplace=True)

# %%
final_rating.shape
# Out:
# (59850, 9)

# %%
final_rating.sample()
# Out:
#       user_id        ISBN Rating                 Title              Author  \
# 67907   55187  0060175400      8  The Poisonwood Bible  Barbara Kingsolver
#
#        Year      publisher                                            Img_url  \
# 67907  1999  HarperCollins  http://images.amazon.com/images/P/0060175400.0...
#
#        Num_of_rating
# 67907             68

# %%
final_rating
# Out:
#        user_id        ISBN Rating  \
# 0       277427  002542730X     10
# 1         3363  002542730X      0
# 2        11676  002542730X      6
# 3        12538  002542730X     10
# 4        13552  002542730X      0
# ...        ...         ...    ...
# 236701  255489  0553579983      7
# 236702  256407  0553579983      0
# 236703  257204  0553579983      0
# 236704  261829  0553579983      0
# 236705  273979  0553579983      0
#
#                                                     Title             Author  \
# 0       Politically Correct Bedtime Stories: Modern Ta...  James Finn Garner
# 1       Politically Correct Bedtime Stories: Modern Ta...  James Finn Garner
# 2       Politically Correct Bedtime Stories: Modern Ta...  James Finn Garner
# 3       Politically Correct Bedtime Stories: Modern Ta...  James Finn Garner
# 4       Politically Correct Bedtime Stories: Modern Ta...  James Finn Garner
# ...                                                   ...                ...
# 236701                                   And Then You Die      Iris Johansen
# 236702                                   And Then You Die      Iris Johansen
# 236703                                   And Then You Die      Iris Johansen
# 236704                                   And Then You Die      Iris Johansen
# 236705                                   And Then You Die      Iris Johansen
#
#         Year                  publisher  \
# 0       1994  John Wiley &amp; Sons Inc
# 1       1994  John Wiley &amp; Sons Inc
# 2       1994  John Wiley &amp; Sons Inc
# 3       1994  John Wiley &amp; Sons Inc
# 4       1994  John Wiley &amp; Sons Inc
# ...      ...                        ...
# 236701  1998                     Bantam
# 236702  1998                     Bantam
# 236703  1998                     Bantam
# 236704  1998                     Bantam
# 236705  1998                     Bantam
#
#                                                   Img_url  Num_of_rating
# 0       http://images.amazon.com/images/P/002542730X.0...             82
# 1       http://images.amazon.com/images/P/002542730X.0...             82
# 2       http://images.amazon.com/images/P/002542730X.0...             82
# 3       http://images.amazon.com/images/P/002542730X.0...             82
# 4       http://images.amazon.com/images/P/002542730X.0...             82
# ...                                                   ...            ...
# 236701  http://images.amazon.com/images/P/0553579983.0...             50
# 236702  http://images.amazon.com/images/P/0553579983.0...             50
# 236703  http://images.amazon.com/images/P/0553579983.0...             50
# 236704  http://images.amazon.com/images/P/0553579983.0...             50
# 236705  http://images.amazon.com/images/P/0553579983.0...             50
#
# [59850 rows x 9 columns]

# %%
final_rating['Rating'] = pd.to_numeric(final_rating['Rating'], errors='coerce')

# %%
book_pivot = final_rating.pivot_table(columns='user_id', index='Title', values='Rating', aggfunc='mean')

# %%
book_pivot
# Out:
# user_id                                             100459  100644  100846  \
# Title
# 1984                                                   NaN     NaN     NaN
# 1st to Die: A Novel                                    NaN     NaN     NaN
# 2nd Chance                                             NaN     0.0     NaN
# 4 Blondes                                              NaN     NaN     NaN
# 84 Charing Cross Road                                  NaN     NaN     NaN
# ...                                                    ...     ...     ...
# Year of Wonders                                        NaN     NaN     NaN
# You Belong To Me                                       NaN     NaN     NaN
# Zen and the Art of Motorcycle Maintenance: An I...     NaN     NaN     NaN
# Zoya                                                   NaN     NaN     NaN
# \O\" Is for Outlaw"                                    NaN     NaN     8.0
#
# user_id                                             100906  101209  101305  \
# Title
# 1984                                                   NaN     NaN     NaN
# 1st to Die: A Novel                                    NaN     NaN     NaN
# 2nd Chance                                             NaN     NaN     NaN
# 4 Blondes                                              NaN     NaN     NaN
# 84 Charing Cross Road                                  NaN     NaN     NaN
# ...                                                    ...     ...     ...
# Year of Wonders                                        9.0     NaN     8.0
# You Belong To Me                                       NaN     NaN     NaN
# Zen and the Art of Motorcycle Maintenance: An I...     NaN     0.0     NaN
# Zoya                                                   NaN     NaN     NaN
# \O\" Is for Outlaw"                                    NaN     NaN     NaN
#
# user_id                                             101851  101876  102275  \
# Title
# 1984                                                   NaN     NaN     NaN
# 1st to Die: A Novel                                    NaN     NaN     NaN
# 2nd Chance                                             NaN     NaN     9.0
# 4 Blondes                                              NaN     NaN     NaN
# 84 Charing Cross Road                                  NaN     NaN     NaN
# ...                                                    ...     ...     ...
# Year of Wonders                                        NaN     NaN     NaN
# You Belong To Me                                       NaN     NaN     0.0
# Zen and the Art of Motorcycle Maintenance: An I...     NaN     NaN     NaN
# Zoya                                                   NaN     NaN     NaN
# \O\" Is for Outlaw"                                    NaN     NaN     NaN
#
# user_id                                             102359  ...  95932  95991  \
# Title                                                       ...
# 1984                                                   NaN  ...    NaN    NaN
# 1st to Die: A Novel                                    NaN  ...    NaN    NaN
# 2nd Chance                                             NaN  ...    NaN    NaN
# 4 Blondes                                              NaN  ...    NaN    NaN
# 84 Charing Cross Road                                  NaN  ...    NaN    NaN
# ...                                                    ...  ...    ...    ...
# Year of Wonders                                        NaN  ...    NaN    NaN
# You Belong To Me                                       NaN  ...    NaN    NaN
# Zen and the Art of Motorcycle Maintenance: An I...     NaN  ...    NaN    NaN
# Zoya                                                   NaN  ...    NaN    NaN
# \O\" Is for Outlaw"                                    NaN  ...    NaN    NaN
#
# user_id                                             96054  96448  97874  \
# Title
# 1984                                                  NaN    NaN    NaN
# 1st to Die: A Novel                                   NaN    NaN    NaN
# 2nd Chance                                            NaN    NaN    NaN
# 4 Blondes                                             NaN    NaN    NaN
# 84 Charing Cross Road                                 NaN    NaN    NaN
# ...                                                   ...    ...    ...
# Year of Wonders                                       NaN    NaN    NaN
# You Belong To Me                                      NaN    NaN    NaN
# Zen and the Art of Motorcycle Maintenance: An I...    NaN    NaN    NaN
# Zoya                                                  NaN    NaN    NaN
# \O\" Is for Outlaw"                                   NaN    NaN    NaN
#
# user_id                                             98297  98391  9856  98741  \
# Title
# 1984                                                  NaN    NaN   NaN    NaN
# 1st to Die: A Novel                                   NaN    NaN   NaN    NaN
# 2nd Chance                                            NaN    9.0   NaN    NaN
# 4 Blondes                                             NaN    NaN   NaN    NaN
# 84 Charing Cross Road                                 NaN    NaN   NaN    NaN
# ...                                                   ...    ...   ...    ...
# Year of Wonders                                       NaN    NaN   NaN    NaN
# You Belong To Me                                      NaN    NaN   NaN    NaN
# Zen and the Art of Motorcycle Maintenance: An I...    NaN    NaN   NaN    NaN
# Zoya                                                  NaN    NaN   NaN    NaN
# \O\" Is for Outlaw"                                   NaN    NaN   NaN    NaN
#
# user_id                                             98758
# Title
# 1984                                                  NaN
# 1st to Die: A Novel                                   NaN
# 2nd Chance                                            NaN
# 4 Blondes                                             NaN
# 84 Charing Cross Road                                 NaN
# ...                                                   ...
# Year of Wonders                                       NaN
# You Belong To Me                                      NaN
# Zen and the Art of Motorcycle Maintenance: An I...    NaN
# Zoya                                                  NaN
# \O\" Is for Outlaw"                                   NaN
#
# [742 rows x 888 columns]

# %%
book_pivot.shape
# Out:
# (742, 888)

# %%
book_pivot.fillna(0, inplace=True)

# %%
book_pivot
# Out:
# user_id                                             100459  100644  100846  \
# Title
# 1984                                                   0.0     0.0     0.0
# 1st to Die: A Novel                                    0.0     0.0     0.0
# 2nd Chance                                             0.0     0.0     0.0
# 4 Blondes                                              0.0     0.0     0.0
# 84 Charing Cross Road                                  0.0     0.0     0.0
# ...                                                    ...     ...     ...
# Year of Wonders                                        0.0     0.0     0.0
# You Belong To Me                                       0.0     0.0     0.0
# Zen and the Art of Motorcycle Maintenance: An I...     0.0     0.0     0.0
# Zoya                                                   0.0     0.0     0.0
# \O\" Is for Outlaw"                                    0.0     0.0     8.0
#
# user_id                                             100906  101209  101305  \
# Title
# 1984                                                   0.0     0.0     0.0
# 1st to Die: A Novel                                    0.0     0.0     0.0
# 2nd Chance                                             0.0     0.0     0.0
# 4 Blondes                                              0.0     0.0     0.0
# 84 Charing Cross Road                                  0.0     0.0     0.0
# ...                                                    ...     ...     ...
# Year of Wonders                                        9.0     0.0     8.0
# You Belong To Me                                       0.0     0.0     0.0
# Zen and the Art of Motorcycle Maintenance: An I...     0.0     0.0     0.0
# Zoya                                                   0.0     0.0     0.0
# \O\" Is for Outlaw"                                    0.0     0.0     0.0
#
# user_id                                             101851  101876  102275  \
# Title
# 1984                                                   0.0     0.0     0.0
# 1st to Die: A Novel                                    0.0     0.0     0.0
# 2nd Chance                                             0.0     0.0     9.0
# 4 Blondes                                              0.0     0.0     0.0
# 84 Charing Cross Road                                  0.0     0.0     0.0
# ...                                                    ...     ...     ...
# Year of Wonders                                        0.0     0.0     0.0
# You Belong To Me                                       0.0     0.0     0.0
# Zen and the Art of Motorcycle Maintenance: An I...     0.0     0.0     0.0
# Zoya                                                   0.0     0.0     0.0
# \O\" Is for Outlaw"                                    0.0     0.0     0.0
#
# user_id                                             102359  ...  95932  95991  \
# Title                                                       ...
# 1984                                                   0.0  ...    0.0    0.0
# 1st to Die: A Novel                                    0.0  ...    0.0    0.0
# 2nd Chance                                             0.0  ...    0.0    0.0
# 4 Blondes                                              0.0  ...    0.0    0.0
# 84 Charing Cross Road                                  0.0  ...    0.0    0.0
# ...                                                    ...  ...    ...    ...
# Year of Wonders                                        0.0  ...    0.0    0.0
# You Belong To Me                                       0.0  ...    0.0    0.0
# Zen and the Art of Motorcycle Maintenance: An I...     0.0  ...    0.0    0.0
# Zoya                                                   0.0  ...    0.0    0.0
# \O\" Is for Outlaw"                                    0.0  ...    0.0    0.0
#
# user_id                                             96054  96448  97874  \
# Title
# 1984                                                  0.0    0.0    0.0
# 1st to Die: A Novel                                   0.0    0.0    0.0
# 2nd Chance                                            0.0    0.0    0.0
# 4 Blondes                                             0.0    0.0    0.0
# 84 Charing Cross Road                                 0.0    0.0    0.0
# ...                                                   ...    ...    ...
# Year of Wonders                                       0.0    0.0    0.0
# You Belong To Me                                      0.0    0.0    0.0
# Zen and the Art of Motorcycle Maintenance: An I...    0.0    0.0    0.0
# Zoya                                                  0.0    0.0    0.0
# \O\" Is for Outlaw"                                   0.0    0.0    0.0
#
# user_id                                             98297  98391  9856  98741  \
# Title
# 1984                                                  0.0    0.0   0.0    0.0
# 1st to Die: A Novel                                   0.0    0.0   0.0    0.0
# 2nd Chance                                            0.0    9.0   0.0    0.0
# 4 Blondes                                             0.0    0.0   0.0    0.0
# 84 Charing Cross Road                                 0.0    0.0   0.0    0.0
# ...                                                   ...    ...   ...    ...
# Year of Wonders                                       0.0    0.0   0.0    0.0
# You Belong To Me                                      0.0    0.0   0.0    0.0
# Zen and the Art of Motorcycle Maintenance: An I...    0.0    0.0   0.0    0.0
# Zoya                                                  0.0    0.0   0.0    0.0
# \O\" Is for Outlaw"                                   0.0    0.0   0.0    0.0
#
# user_id                                             98758
# Title
# 1984                                                  0.0
# 1st to Die: A Novel                                   0.0
# 2nd Chance                                            0.0
# 4 Blondes                                             0.0
# 84 Charing Cross Road                                 0.0
# ...                                                   ...
# Year of Wonders                                       0.0
# You Belong To Me                                      0.0
# Zen and the Art of Motorcycle Maintenance: An I...    0.0
# Zoya                                                  0.0
# \O\" Is for Outlaw"                                   0.0
#
# [742 rows x 888 columns]

# %%
from scipy.sparse import csr_matrix

# %%
book_sparse = csr_matrix(book_pivot)

# %%
book_sparse
# Out:
# <742x888 sparse matrix of type '<class 'numpy.float64'>'
# 	with 14942 stored elements in Compressed Sparse Row format>

# %%
from sklearn.neighbors import NearestNeighbors
model = NearestNeighbors(algorithm='brute')

# %%
model.fit(book_sparse)
# Out:
# NearestNeighbors(algorithm='brute')

# %%
distance, suggestion = model.kneighbors(book_pivot.iloc[237,:].values.reshape(1,-1), n_neighbors=6)

# %%
distance
# Out:
# array([[ 0.        , 68.78953409, 69.5413546 , 72.64296249, 76.83098333,
#         77.28518616]])

# %%
suggestion
# Out:
# array([[237, 240, 238, 241, 184, 536]], dtype=int64)

# %%
for i in range(len(suggestion)):
    print(book_pivot.index[suggestion[i]])
# Out:
# Index(['Harry Potter and the Chamber of Secrets (Book 2)',
#        'Harry Potter and the Prisoner of Azkaban (Book 3)',
#        'Harry Potter and the Goblet of Fire (Book 4)',
#        'Harry Potter and the Sorcerer's Stone (Book 1)', 'Exclusive',
#        'The Cradle Will Fall'],
#       dtype='object', name='Title')

# %%
book_pivot.index[3]
# Out:
# '4 Blondes'

# %%
books_name = book_pivot.index

# %%
import pickle
pickle.dump(model, open('artifacts/model.pkl', 'wb'))
pickle.dump(books_name, open('artifacts/books_name.pkl', 'wb'))
pickle.dump(final_rating, open('artifacts/final_rating.pkl', 'wb'))
pickle.dump(book_pivot, open('artifacts/book_pivot.pkl', 'wb'))

# %%
def recommend_book(book_name):
    book_id= np.where(book_pivot.index == book_name)[0][0]
    distance, suggestion = model.kneighbors(book_pivot.iloc[book_id,:].values.reshape(1,-1), n_neighbors=6)

    for i in range(len(suggestion)):
        books = book_pivot.index[suggestion[i]]
        for j in books:
            print(j)

# %%
book_name = 'You Belong To Me'
recommend_book(book_name)
# Out:
# You Belong To Me
# The Cradle Will Fall
# Exclusive
# Loves Music, Loves to Dance
# While My Pretty One Sleeps
# Before I Say Good-Bye
